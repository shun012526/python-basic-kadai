# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i = 0

for planet in array:
  print(planet)

while i < len(array):
  print(array[i])
  i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
